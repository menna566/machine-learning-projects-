# %% [markdown]
# <a href="https://www.kaggle.com/code/mennamostafa3/ibm-hr-eda?scriptVersionId=104497493" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt  
import seaborn as sns
from plotnine import *
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename)) 
        f_name=os.path.join(dirname,filename)
# Out:
# /opt/conda/lib/python3.7/site-packages/geopandas/_compat.py:115: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
# /kaggle/input/hranalytics/WA_Fn-UseC_-HR-Employee-Attrition.csv

# %%
data=pd.read_csv(f_name)
data.head(20)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# 5    32        No  Travel_Frequently       1005  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 7    30        No      Travel_Rarely       1358  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
# 11   29        No      Travel_Rarely        153  Research & Development
# ...

# %% [markdown]
# ### The last elements in the data

# %%
data.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %% [markdown]
# ### info() method shows The data types of all the features in the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ### The data has No Null Values ###

# %%
data.isnull()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %% [markdown]
# ### Checking if there any duplicates

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data["Attrition"].replace("Yes",1,inplace=True)
data["Attrition"].replace("No",0,inplace=True)

# %% [markdown]
# ### How many people left the job and How many of them stayed ?

# %%
data['Attrition'].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %% [markdown]
# ### The percentage of those who stayed is 83.8 the percentage of the people who left is 16.12 but the comapny still have a problem to work on because its not small percentage ###

# %%
plt.figure(figsize= (10, 6))
data_pie  = [237 , 1233]
labels = ["Yes", "No"]
explode = [0.1, 0]
plt.pie(data_pie ,labels= labels , explode = explode , autopct="%1.2f%%", shadow= True, colors= ['#256D85', '#3BACB6'])
plt.legend()
plt.show()

# %% [markdown]
# ### who leave the campany more Males or Females ? ###

# %%
data[(data['Gender']=="Male") & (data['Attrition']==1)]
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 2      37          1      Travel_Rarely       1373  Research & Development
# 14     28          1      Travel_Rarely        103  Research & Development
# 21     36          1      Travel_Rarely       1218                   Sales
# 24     34          1      Travel_Rarely        699  Research & Development
# 33     39          1      Travel_Rarely        895                   Sales
# ...   ...        ...                ...        ...                     ...
# 1438   23          1  Travel_Frequently        638                   Sales
# 1442   29          1      Travel_Rarely       1092  Research & Development
# 1444   56          1      Travel_Rarely        310  Research & Development
# 1452   50          1  Travel_Frequently        878                   Sales
# 1461   50          1      Travel_Rarely        410                   Sales
#
# ...

# %% [markdown]
# ### The Number of Males is Bigger than The Females

# %%
data[(data['Gender']=="Female") & (data['Attrition']==1)]
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 26     32          1  Travel_Frequently       1125  Research & Development
# 45     41          1      Travel_Rarely       1360  Research & Development
# 102    20          1  Travel_Frequently        871  Research & Development
# 122    56          1      Travel_Rarely        441  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1298   46          1      Travel_Rarely        261  Research & Development
# 1333   46          1      Travel_Rarely       1254                   Sales
# 1369   28          1      Travel_Rarely       1475                   Sales
# 1375   32          1  Travel_Frequently        238  Research & Development
# 1379   27          1  Travel_Frequently       1337         Human Resources
#
# ...

# %% [markdown]
# ### The percntage of the Females who left the job less than the percentage of males

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Attrition", hue='Gender', data=data)

# %% [markdown]
# ### Does the people leave because of their salary ?

# %%
data['MonthlyIncome'].describe()
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
df=data[['Attrition','MonthlyIncome','MonthlyRate','DailyRate']]
sns.heatmap(df.corr() ,annot=True)
plt.figure(figsize=(50,50))

# %% [markdown]
# ### 2% just of the people who left had good Monthly Income but the rest of them has really
#
# ### Bad Monthly income

# %%
sns.catplot(x="Attrition", y="MonthlyIncome", data=data,alpha=0.7)

# %% [markdown]
# ### Is they have a bad Daily rate so that they have low Monthly Income ?

# %% [markdown]
# ### Despite working the same Daily Rate as the others they have low Monthly Income

# %%
sns.catplot(x="Attrition", y="MonthlyIncome", kind="box", data=data,palette='cubehelix')
sns.catplot(x="Attrition", y="DailyRate", data=data,palette='cubehelix')

# %% [markdown]
# ### Do they Take Overtime ?

# %% [markdown]
# ### 5% of the people that left took overtime but its not effictive as the Monthly income

# %%
ax = sns.countplot(x="Attrition", data=data,hue="OverTime",palette='spring')
for container in ax.containers:
     ax.bar_label(container)

# %% [markdown]
# ### How many years they satyed at  the company untill they left ?
#
# ### what age most of them intend to leave at ?

# %%
data[(data['Age']>=20) & (data['YearsAtCompany']>=5) & data['Attrition']==1]
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 21     36          1      Travel_Rarely       1218                   Sales
# 26     32          1  Travel_Frequently       1125  Research & Development
# 45     41          1      Travel_Rarely       1360  Research & Development
# 89     46          1      Travel_Rarely        669                   Sales
# ...   ...        ...                ...        ...                     ...
# 1333   46          1      Travel_Rarely       1254                   Sales
# 1353   34          1         Non-Travel        967  Research & Development
# 1395   31          1  Travel_Frequently        754                   Sales
# 1444   56          1      Travel_Rarely        310  Research & Development
# 1452   50          1  Travel_Frequently        878                   Sales
#
# ...

# %% [markdown]
# ### The people who stayed from 1-10 years leave quickly more than the others

# %%
sns.kdeplot(data[data['Attrition'] == 0]['YearsAtCompany'], shade=True,color='b')
sns.kdeplot(data[(data['Attrition'] == 1)]['YearsAtCompany'], shade=True,color='r')
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='Density'>

# %% [markdown]
# ### The people from 20-30 mostly leave the company more than others

# %%
sns.kdeplot(data[data['Attrition'] == 0]['Age'],color='r')
sns.kdeplot(data[(data['Attrition'] == 1)]['Age'],color='g')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### Is there a relation between the years they spend in the company and getting a promotion?

# %%
ax = sns.countplot(x="YearsSinceLastPromotion", data=data,hue="Attrition", palette='winter')

# %% [markdown]
# ### Apperently the longer you are in the company less chance you have to be promoted
#
# ### may mean that people are not really growing within the company

# %%
# high correlation between these two features
ax = sns.stripplot(x="YearsSinceLastPromotion", y="YearsAtCompany", data=data,palette="Set2")

# %% [markdown]
# ### Higher correlation between years since last promotion and years at company for those who don't work overtime

# %%
ax =  sns.stripplot(x="YearsSinceLastPromotion", y="YearsAtCompany", hue="OverTime",
                   data=data, palette="Set2", size=20, marker="D",
                   edgecolor="gray", alpha=.25)

# %% [markdown]
# ### Which Department they leave most from ?

# %%
round(data['Department'].value_counts()/ data.shape[0]*100,2).plot.pie(autopct = '%1.1f')
# Out:
# <AxesSubplot:ylabel='Department'>

# %% [markdown]
# ### around 20% of Hrs leave and its not small percetage
#
# ### because the campany dont have high  number of hrs as we saw in the plot above their
#
# ### percentage only 4.3%

# %%
plt.figure(figsize=(12,4))
ax = sns.countplot(x="Department", data=data,hue="Attrition",palette="husl")
for container in ax.containers:
     ax.bar_label(container)

# %% [markdown]
# ### Is the reason of hrs leaving has anything to do with the salary ?

# %% [markdown]
# ### Yes,the Hr department employees has low Monthly Income and here is the proof :

# %%
sns.displot(data=data, x="MonthlyIncome", hue="Department", kind="kde")

# %% [markdown]
# ### The features that i thought the employess were sending the company warning
#
# ### through it before they leave

# %% [markdown]
# ### LOW OF WORK LIFE BALANCE RATE

# %%
ax = sns.countplot(x="Attrition", data=data,hue="WorkLifeBalance",palette='Set1')

# %% [markdown]
# ### THE LOW OF JOB SATISFACTION RATE

# %%
ax = sns.countplot(x="Attrition", data=data,hue="JobSatisfaction",color='darkred')

# %% [markdown]
# ### DATA INSIGHTS

# %% [markdown]
# ### What factors are contributing more to employee attrition?

# %% [markdown]
# ### 1-MonthlyIncome Feature as they have low monthly income despite they work as the others
#
#
#   ### with the same hours
#
#  ### 2-YearsSinceLastPromotion and YearsAtCompany Features as we saw the environment isnt good
#
#   ### to grow out your experience in so no matter how many years you stayed at the company
#
#   ### you wont have that much of opportunities to get evolved
#
# ### 3-age and years at company features show us that most people who is between 20-30
#
#   ### leave the company between the first 1-10 years another proof that the environment
#
#   ### doesnt help people to grow

# %% [markdown]
# ### What type of measures should the company take in order to retain their employees?

# %% [markdown]
# ### -Make the environment more growing and less pressured so they can have good life
# ###    balance and they can get prometed to more evolving positions that will help them grow
# ### -increase the number of Hrs and the salary of hrs as the other departments

# %% [markdown]
# ### What business value does the model bring?

# %% [markdown]
# ### -incresing the accuracy of this model will make the company more aware
#
# ### why the employes are leaving so they can focus on the importnat features
#
#  ### and solve their problems

# %% [markdown]
# ### Will the model save lots of money?

# %% [markdown]
# ### -Yes, because it will help not to do the whole recuriment process which costs a lot

# %% [markdown]
# ### CONCLUSION

# %% [markdown]
# ### - The Company needs to Change her Staratgy and get the best it can from its Employees
#
# ### Without pressure them into Getting Non_work life Balance
#
#
# ### - They need to Create More Effective Methods to make them grow their Experience
#
#   ###  each year they spend there
#
#
# ### - They need to Raise the salary at least raise it to a point that will make Balance
#
#
# ###  that each Department has the Percentage of the Good = The Percentage of the Bad
#
#
# ### Salaries to make it more Normally Distrbuted and fill in the Gaps that you have now and
#
#
# ###  to be Fair to your employees too
