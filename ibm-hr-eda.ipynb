# %% [markdown]
# <a href="https://www.kaggle.com/code/mennamostafa3/ibm-hr-eda?scriptVersionId=104378429" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Pabsython 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd 
import matplotlib.pyplot as plt  
import seaborn as sns
from plotnine import *
# data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename)) 
        f_name=os.path.join(dirname,filename)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /opt/conda/lib/python3.7/site-packages/geopandas/_compat.py:115: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
# /kaggle/input/hranalytics/WA_Fn-UseC_-HR-Employee-Attrition.csv

# %%
data=pd.read_csv(f_name)
data.head(40)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# 5    32        No  Travel_Frequently       1005  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 7    30        No      Travel_Rarely       1358  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
# 11   29        No      Travel_Rarely        153  Research & Development
# ...

# %%
data.tail()
#the last elements in the data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
data.info()
#the data types of all the features in the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.isnull()
#there is no null value
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
#the sum of the null values in the data (additional)
data['DistanceFromHome'].isnull().sum()
# Out:
# 0

# %%
#to help me to get the percentage of how many people left the job and how many pof them stayed
data['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
data["Attrition"].replace("Yes",1,inplace=True)
data["Attrition"].replace("No",0,inplace=True)

# %%
'''the percentage tells me that 16,12% of employees left the job at IBM 
and 83.88 still working there'''
plt.figure(figsize= (10, 6))
data_pie  = [237 , 1233]
labels = ["Yes", "No"]
explode = [0.1, 0]
plt.pie(data_pie ,labels= labels , explode = explode , autopct="%1.2f%%", shadow= True, colors= ['#256D85', '#3BACB6'])
plt.legend()
plt.show()

# %%
data[(data['Gender']=="Male") & (data['Attrition']==1)]
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 2      37          1      Travel_Rarely       1373  Research & Development
# 14     28          1      Travel_Rarely        103  Research & Development
# 21     36          1      Travel_Rarely       1218                   Sales
# 24     34          1      Travel_Rarely        699  Research & Development
# 33     39          1      Travel_Rarely        895                   Sales
# ...   ...        ...                ...        ...                     ...
# 1438   23          1  Travel_Frequently        638                   Sales
# 1442   29          1      Travel_Rarely       1092  Research & Development
# 1444   56          1      Travel_Rarely        310  Research & Development
# 1452   50          1  Travel_Frequently        878                   Sales
# 1461   50          1      Travel_Rarely        410                   Sales
#
# ...

# %%
#the percntage of the Females who left the job less than the percentage of males 
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Attrition", hue='Gender', data=data)

# %%
#most of the employees who didnt leave have good montlyincome but those who left 5% of them just has high income the others were around the avarage
sns.catplot(x="Attrition", y="MonthlyIncome", data=data)

# %%
sns.lineplot(data=data, x="DailyRate", y="MonthlyIncome",hue="Attrition")
# Out:
# <AxesSubplot:xlabel='DailyRate', ylabel='MonthlyIncome'>

# %%
#if we connected the dots we will find a relation between the dailyrate and decreasing the monthly income 
#as they work very hard so their daily rate is high but still thier salary is low 
sns.catplot(x="Attrition", y="DailyRate", kind="box", data=data)
sns.catplot(x="Attrition", y="DailyRate", data=data)

# %%
#5% of the people that left took overtime
#maybe we will try to give more people overtime so less people leave
ax = sns.countplot(x="Attrition", data=data,hue="OverTime",palette='spring')
for container in ax.containers:
     ax.bar_label(container)

# %%
#the more you stay at the company less chance you have to be promoted may mean that people are not really growing within the company
ax = sns.countplot(x="YearsSinceLastPromotion", data=data,hue="Attrition", palette='winter')

# %%
#15% of people who leave travel rerely maybe we should give them more work trips to raise their salary 
ax = sns.countplot(x="Attrition", data=data,hue="BusinessTravel",palette='spring')

# %%
'''high correlation between these two features
apperently the longer you are in the company less chance you have to be promoted
may mean that people are not really growing within the company'''

ax = sns.stripplot(x="YearsSinceLastPromotion", y="YearsAtCompany", data=data,palette="Set2")

# %%
#higher correlation between years since last promotion and years at company for those who don't work overtime
ax =  sns.stripplot(x="YearsSinceLastPromotion", y="YearsAtCompany", hue="OverTime",
                   data=data, palette="Set2", size=20, marker="D",
                   edgecolor="gray", alpha=.25)
'''g = sns.catplot(x="YearsSinceLastPromotion", y="YearsAtCompany",
                hue="OverTime",
                data=data, kind="strip",
                height=4, aspect=.7); '''
# Out:
# 'g = sns.catplot(x="YearsSinceLastPromotion", y="YearsAtCompany",\n                hue="OverTime",\n                data=data, kind="strip",\n                height=4, aspect=.7); '

# %%
#the more work life balance they have the more they wont leave the job
ax = sns.countplot(x="Attrition", data=data,hue="WorkLifeBalance",palette='spring')

# %%
ax = sns.countplot(x="Attrition", data=data,hue="JobSatisfaction",palette='spring')

# %%
#insights 
'''
What factors are contributing more to employee attrition?
1-MonthlyIncome and dailyrate
2-Overtime
3-YearsSinceLastPromotion
4-Business travel
2. What type of measures should the company take in order to retain their employees?
-give them more overtime to raise their salary
-make the environment more growing so they can get prometed
3. What business value does the model bring?
-incresing the accuracy of this model will make the company 
more aware why the employes are leaving so they can focus on the importnat features and solve their problems
4. Will the model save lots of money?
-yes becuse it will help not to do the whole recuriment process which costs a lot
'''
# Out:
# '\nWhat factors are contributing more to employee attrition?\n1-MonthlyIncome and dailyrate\n2-Overtime\n3-YearsSinceLastPromotion\n4-Business travel\n2. What type of measures should the company take in order to retain their employees?\n-give them more overtime to raise their salary\n-make the environment more growing so they can get prometed\n3. What business value does the model bring?\n-incresing the accuracy of this model will make the company \nmore aware why the employes are leaving so they can focus on the importnat features and solve their problems\n4. Will the model save lots of money?\n-yes becuse it will help not to do the whole recuriment process which costs a lot\n'
